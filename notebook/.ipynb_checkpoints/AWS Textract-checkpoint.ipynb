# %% [markdown]
# ## AWS Credentials
# Check that you have entered the proper credentials in your local

# %%
AWS_ACCESS_KEY_ID="ASIAYIZMYGJZ622O3YUD"
AWS_SECRET_ACCESS_KEY="18QV1FAaTACau75FyHW8SxhxDaievgL2Gbb8nSRM"
AWS_SESSION_TOKEN="..."
AWS_DEFAULT_REGION="ap-southeast-1"

# %%
BUCKET_NAME = 'document-scanning-az'

# %% [markdown]
# Only need to run once if have yet to install

# %%
# !pip install amazon-textract-response-parser
# !pip install amazon-textract-prettyprinter
# !pip install amazon-textract-caller
# !pip install pandas

# %% [markdown]
# # Importing dependencies
# Necessary dependencies are imported and we initialize the aws service to be used lated

# %%
import boto3
import botocore
import json
import time
import pandas as pd

# from trp.trp2 import TDocument, TDocumentSchema
# from trp.t_pipeline import order_blocks_by_geo
# from trp import Document
from textractprettyprinter.t_pretty_print import Textract_Pretty_Print, get_string
from textractcaller import get_full_json, Textract_API

# t_doc = TDocumentSchema().load(j)

# %%
session = boto3.session.Session(
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    aws_session_token=AWS_SESSION_TOKEN,
)

textract = session.client("textract", region_name = AWS_DEFAULT_REGION )
s3 = session.client("s3", region_name = AWS_DEFAULT_REGION)

# %% [markdown]
# # Upload report to S3
# Upload file from local machine to S3 if file has yet to be uploaded

# %%
filename = 'dsv'
upload_prefix = 'raw-reports/'
file_ref_raw_file = upload_prefix + filename + '.pdf'
local_file_ref = file_ref_raw_file

try:
    s3.get_object(
        Bucket= BUCKET_NAME,
        Key= file_ref_raw_file
    )
    print("File already uploaded to S3")
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "NoSuchKey":
        print("Uploading to S3")
        with open(local_file_ref, "rb") as f:
            s3.upload_fileobj(f, BUCKET_NAME, file_ref_raw_file)
        print("Uploaded to S3")
    if e.response['Error']['Code'] == "ExpiredToken":
        print("Expired Token")


print("File is at: ", file_ref_raw_file);
# Out:
# File already uploaded to S3
# File is at:  raw-reports/dsv.pdf

# %% [markdown]
# # Textract function
# Function to textract file asynchronously and fetch block response. Although the function to start analysis is done asynchronously, getting full json requires waiting till the job is completed.
#
# For future use in the cloud, a notification can be set up to notify completion of extraction

# %%
def textract_file(file_ref):
    doc_textracted_async = textract.start_document_analysis(
        DocumentLocation={
            'S3Object':{
                'Bucket': BUCKET_NAME,
                'Name': file_ref
            }
        },
        FeatureTypes=['TABLES']
    )
    job_id = doc_textracted_async["JobId"]
    all_blocks = []
    print("getting full_json")
    response = get_full_json(job_id, Textract_API.ANALYZE, textract)
    return response

# %% [markdown]
# # Textract file
# Get textracted file if exist from S3, else textract and upload

# %%
upload_textracted_prefix = 'textracted-reports-values/'
file_ref_tetracted = upload_textracted_prefix + filename + '.json'

document_json = {}

try:
    document_json = s3.get_object(
        Bucket= BUCKET_NAME,
        Key= file_ref_tetracted
    )
    document_json = json.loads(document_json["Body"].read().decode('UTF-8'))
    print("File already textracted")
    
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "NoSuchKey":
        print("Textracting.....")
        document_json = textract_file(file_ref_raw_file)
        print("Textracted")

        json_file = json.dumps(document_json).encode('UTF-8')

        s3.put_object(
            Body = json_file,
            Bucket = BUCKET_NAME,
            Key = file_ref_tetracted
        )
        print("File uploaded at: ", file_ref_tetracted)
all_blocks = document_json["Blocks"]
# Out:
# File already textracted

# %% [markdown]
# # Visualizing all tables

# %%
print(get_string(textract_json=document_json, output_type=[Textract_Pretty_Print.TABLES]))
# Out:
# |----------------------------|------|------|------|------|------|
# | Environmental data*        | 2021 | 2020 | 2019 | 2018 | 2017 |
# | CO2 Scope 1 ('000 tonnes)  |      |      |      |      |      |
# | Company cars**             | 10   | 13   | 14   | -    | -    |
# | Road emissions (own fleet) | 101  | 43   | 37   | 39   | 39   |
# | Building emissions         | 24   | 24   | 23   | 22   | 19   |
# | Total CO, e Scope 1        | 135  | 80   | 74   | 61   | 58   |
# | CO2 Scope 2 ('000 tonnes)  |      |      |      |      |      |
# | Building emissions         | 119  | 98   | 85   | 78   | 78   |
# | Total CO2 e Scope 2        | 119  | 98   | 85   | 78   | 78   |
#
# |----------------------------|--------|--------|-------|-------|-------|
# | Environmental data*        | 2021   | 2020   | 2019  | 2018  | 2017  |
# | CO2e Scope 3 ('000 tonnes) |        |        |       |       |       |
# | Business travel**          | 1      | 1      | 8     | -     | -     |
# ...

# %% [markdown]
# # Create a dictionary for block
# Dictionary for block is created to extract blocks by Id

# %%
all_blocks_dict_by_id = {}
for block in all_blocks:
    all_blocks_dict_by_id[block["Id"]]=block

# %% [markdown]
# # Extract text from merge cells
# AWS textract returns us merge cells detected in the tables. We would replicate the entries of all merge cells into the normal cells as we wont be able to process merge cells here

# %%
# i want to go into a merge cell and replicate for the space
def extract_child_ids_if_present(block):
    
    try:       
        return block["Relationships"][0]["Ids"]
    except:
        return None

# get text of cell
def get_text_from_cell_ids(cell_ids, all_blocks_dict_by_id):
    word_ids = []
    
    for cell_id in cell_ids:
        child_id = extract_child_ids_if_present(all_blocks_dict_by_id[cell_id])
        if child_id != None:
            word_ids += child_id
            
    word_arr = [all_blocks_dict_by_id[word_id]["Text"] for word_id in word_ids]
    
    return (' ').join(word_arr)

# get text, row idx, row span, col idx, col span
def get_details_from_merge_cell(merge_block_id, all_blocks_dict_by_id):

    merge_block = all_blocks_dict_by_id[merge_block_id]
    
    #find all child id
    child_ids = merge_block["Relationships"][0]["Ids"]
    text = get_text_from_cell_ids(child_ids, all_blocks_dict_by_id)
    
#     return{
#         'Text': text,
#         'RowIndex': merge_block["RowIndex"],
#         'ColumnIndex': merge_block["ColumnIndex"],
#         'RowSpan': merge_block["RowSpan"],
#         'ColumnSpan': merge_block["ColumnSpan"],
#     }
    return [text, merge_block["RowIndex"], merge_block["ColumnIndex"], merge_block["RowSpan"], merge_block["ColumnSpan"]]

# %%
## from trp import Document
# from array import *
# import numpy as np

# doc = Document(document_json)

# table_num = 0

# all_array = []


# # Iterate over elements in the document
# for p, page in enumerate(doc.pages):
#     for t, table in enumerate(page.tables):
#         table_array = []
# #         print("Table number: {}".format(t+1))
#         for r, row in enumerate(table.rows):
#             row_array = []
#             for c, cell in enumerate(row.cells):
#                 row_array.append(cell.text.strip())
#             table_array.append(row_array)
#         all_array.append(table_array)
        
# print("Number of tables", len(all_array))

# %%
# # row_idx = 
# relations = table_block['Relationships']
# child_ids = []
# merged_cells_ids= []

# for relation in relations:
#     if relation["Type"] == "CHILD":
#         child_ids = relation["Ids"]
#     elif relation["Type"] == "MERGED_CELL":
#         merged_cells_ids = relation["Ids"]

# current_row = 1
# table_array = []
# row_array = []

# for cell_id in child_ids:
#     blocks = all_blocks_dict_by_id[cell_id]
    
#     text = get_text_from_cell_ids([cell_id],all_blocks_dict_by_id)
#     row_index =  blocks["RowIndex"]
#     column_index = blocks["ColumnIndex"]
    
#     if current_row == row_index:
#         row_array.append(text)
#     else:
#         table_array.append(row_array)
#         row_array = [text]
#         current_row = row_index
    
# table_array.append(row_array)

# if(len(merged_cells_ids)>0):
#     for merged_cell_id in merged_cells_ids:
#         text, row_idx, col_idx, row_span, col_span  = get_details_from_merge_cell(merged_cell_id, all_blocks_dict_by_id)
#         print(text, row_idx, col_idx, row_span, col_span)

#         row_idx_start = row_idx-1
#         row_idx_end = row_idx-1 + row_span
#         for row_idx in range(row_idx_start, row_idx_end):
#             table_array[row_idx][col_idx-1] = text

# %%
table_blocks = [block for block in all_blocks if block["BlockType"] == "TABLE"]

all_table_arrays = []

# for all tables return by textract:
for idx, table_block in enumerate(table_blocks):
    relations = table_block['Relationships']
    child_ids = []
    merged_cells_ids = []

    # check for child and merge cell relationship
    for relation in relations:
        if relation["Type"] == "CHILD":
            child_ids = relation["Ids"]
        elif relation["Type"] == "MERGED_CELL":
            merged_cells_ids = relation["Ids"]

    current_row = 1
    table_array = []
    row_array = []

    
    # compile cells into array
    for cell_id in child_ids:
        blocks = all_blocks_dict_by_id[cell_id]

        text = get_text_from_cell_ids([cell_id],all_blocks_dict_by_id)
        row_index =  blocks["RowIndex"]
        column_index = blocks["ColumnIndex"]

        if current_row == row_index:
            row_array.append(text)
        else:
            table_array.append(row_array)
            row_array = [text]
            current_row = row_index

    table_array.append(row_array)

    # refactor cells that has merged values (currently only for row)
    for merged_cell_id in merged_cells_ids:
        text, row_idx, col_idx, row_span, col_span  = get_details_from_merge_cell(merged_cell_id, all_blocks_dict_by_id)
#         print(text, row_idx, col_idx, row_span, col_span)

        row_idx_start = row_idx-1
        row_idx_end = row_idx-1 + row_span
        for row_idx in range(row_idx_start, row_idx_end):
            table_array[row_idx][col_idx-1] = text
            
    # combine all table        
    all_table_arrays.append(table_array)

# %% [markdown]
# # Visualizing each table after refactoring merge cells one by one

# %%
n=0
# print(n)

# %% [markdown]
# ### continue pressing ctrl + Enter to iterate to the next table

# %%
try:
    arr_np = np.array(all_table_arrays[n])
    df = pd.DataFrame(arr_np[1:], columns=arr_np[0])
    n +=1
except:
    print("End of table reached")
df
# Out:
#           Environmental data* 2021 2020 2019 2018 2017
# 0   CO2 Scope 1 ('000 tonnes)
# 1              Company cars**   10   13   14    -    -
# 2  Road emissions (own fleet)  101   43   37   39   39
# 3          Building emissions   24   24   23   22   19
# 4         Total CO, e Scope 1  135   80   74   61   58
# 5   CO2 Scope 2 ('000 tonnes)
# 6          Building emissions  119   98   85   78   78
# 7         Total CO2 e Scope 2  119   98   85   78   78

# %% [markdown]
# # Key Word Mapping
# List down keywords to extract from the table. All keys in list have to exist.

# %%
year = 2021
sample_keywords = {
    "Total Scope 1 GHG emissions":['Total', 'Scope 1'],
    "Total Scope 2 GHG emissions":['Total', 'Scope 2'],
    "Total Scope 3 GHG emissions":['Total', 'Scope 3'],
    "Total electricity consumption (MWh)":['Total', 'energy','consumption'],
    "Total water consumption (m3)":['Total', 'water', 'consumption'],
#     "Total waste generated (tonnes)":[],
#     "Total Hazardous waste (tonnes)":[],
#     "Total Non-Hazardous waste (tonnes)":[],
    "Current gender diversity (female/male) (%)":['gender', 'diversity', 'total'],
    "Current gender diversity in management (female/male) (%)":['gender', 'diversity', 'management'],
    "Number of severe injury":["fatalities", "absolute", "number"]
#     "%of employees by age group (%)":[],
#     "Average training hours per employee (hours)":[],
#     "Turnover rate (%)":[],
#     "%women on the board (%)":[],
#     "%women in Management (%)":[],
#     "Number of corruption case":[]    
}

# %%
import re

def is_year(number):
    if re.match(r"(19|20|21)[0-9]{2}", number) and len(number)==4:
        return True
    else:
        False
    
# returns False if not found
# return location of year and key location if found
def loc_for_year_header(year, table_array):
    year_loc_row = {}
    year_loc_col = {}
    
    num_of_rows = len(table_array)
    num_of_col = len(table_array[0])
    
    array_year = np.zeros((num_of_rows, num_of_col))
    for row_id, row in enumerate(table_array):
        
        for col_id, elem in enumerate(row):
            if is_year(elem):
                array_year[row_id][col_id] = 1
                if str(elem) == str(year):
                    # in case we have elements with year format above
                    try:
                        year_loc_row[row_id].extend([col_id])
                        year_loc_col[col_id].extend([row_id])
                    except:
                        year_loc_row[row_id] = [col_id]
                        year_loc_col[col_id] = [row_id]
                                            
    # in future, need to factor in if year is not in first col or first row
    row_sum = np.sum(array_year, axis = 0)[0] #row sum
    col_sum = np.sum(array_year, axis = 1)[0] #col sum
    
    #only support year in 1 year or 1 col
    if row_sum > col_sum: #year is in first col
        row_idxs = year_loc_col[0]
        if len(row_idxs) != 1:
            return False
        else:
            return ((row_idxs[0], 0), "row")
    else: #year is in first row
        col_idxs = year_loc_row[0]
        if len(col_idxs) != 1:
            return False
        else:
            return ((0, col_idxs[0]), "col")

# %%
year_loc, key_loc = loc_for_year_header(year, arr_np)
# print(year_loc, key_loc)

header_mapping = {}
filtered_table_array = []

for table_arr in all_table_arrays:
    if key_loc == 'col':
        for row in table_arr:
            table_key = row[0].lower()
            for key in sample_keywords:
    #             print("key", key)
                is_table_key = 1
                for values in sample_keywords[key]:
#                     print("values", values)
                    if values.lower() not in table_key:
                        is_table_key = 0
    #                     print("values not in /", table_key)
                        break
    #                 print("in value for loop")
#                     print("values", values, table_key)
                if is_table_key:
                    if row[year_loc[1]] != '':
                        header_mapping[key]=table_key
                        filtered_table_array.append([key] + row[1:])
#                     print(key, row[year_loc[1]])
                    
    #             print("in key for loop")

# %%
df = pd.DataFrame(np.array(filtered_table_array), columns=arr_np[0])
df
# Out:
#                                  Environmental data*    2021    2020   2019  \
# 0                        Total Scope 1 GHG emissions     135      80     74
# 1                        Total Scope 2 GHG emissions     119      98     85
# 2                        Total Scope 3 GHG emissions  12,524  11,287  8,728
# 3                Total electricity consumption (MWh)   2,800   1,673      -
# 4                       Total water consumption (m3)   1,188   1,152  1,596
# 5         Current gender diversity (female/male) (%)   38/62   38/62  39/61
# 6  Current gender diversity in management (female...   34/66   34/66  33/67
# 7                            Number of severe injury       1       0      1
#
#     2018   2017
# 0     61     58
# 1     78     78
# 2  7,126  7,050
# 3      -      -
# 4  1,485  1,435
# 5  38/62  39/61
# 6  28/72  31/69
# 7      0      0

# %% [markdown]
# # Below code are junk

# %%
import re

def is_header_years(header_array):
    is_years = True
    for idx, i in enumerate(header_array):
        if idx>0:
            if not re.match(r"(19|20|21)[0-9]{2}", i) or len(i)!=4:
                is_years = False
                break

    return is_years


# format year to be in 1st row

tables_with_year = []
tables_without_year = []


for idx, table in enumerate(all_array):
    suspect_header = table[0]
    if not is_header_years(suspect_header):
        table = np.transpose(np.array(table))
        suspect_header = table[0]
        if not is_header_years(suspect_header):
            tables_without_year.append(table)
            continue
    
    table[0][0] = "Year"
    tables_with_year.append(table)

# %%
tables_without_year
# Out:
# [array([['METRIC', 'Operational energy consumption/MWh',
#          'Scope 2 carbon emissions / tonne of carbon dioxide (tCO)',
#          'Portfolio carbon emissions2/ tCO2 equivalent (tCO2e)',
#          'Portfolio carbon intensity3/tCO26 per mil dollars in sales'],
#         ['FY2021', '502', '205', '10,348,920', '291.5']], dtype='<U58')]

# %%
tables = tables_with_year
df_arr = []
for arr in tables_with_year:   
    arr_np = np.array(arr)
    arr_np = np.transpose(arr_np)
    df = pd.DataFrame(arr_np[1:], columns=arr_np[0])
    df_arr.append(df)
    
df_merge = df_arr[0]
for df in df_arr[1:]:
    df_merge = pd.merge(df_merge, df, on='Year')
    
df_merge
# pd.merge(df_arr[0], df_arr[1], on='Year')
# Out:
# C:\Users\azmi_\AppData\Local\Temp\ipykernel_45092\1682651941.py:11: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Total_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merge = pd.merge(df_merge, df, on='Year')
#    Year CO2 Scope 1 ('000 tonnes) Company cars** Road emissions (own fleet)  \
# 0  2021                                       10                        101
# 1  2020                                       13                         43
# 2  2019                                       14                         37
# 3  2018                                        -                         39
# 4  2017                                        -                         39
#
#   Building emissions Total CO, e Scope 1 CO2 Scope 2 ('000 tonnes)  \
# 0                 24                 135
# 1                 24                  80
# 2                 23                  74
# 3                 22                  61
# ...

# %%
import os  
os.makedirs('export', exist_ok=True)  
df_merge.to_csv('export/' + filename + '.csv')

# %% [markdown]
# ## Trying Document module

# %%
all_blocks[]
# Out:
# {'BlockType': 'LINE',
#  'Confidence': 99.83625793457031,
#  'Text': 'Sustainable',
#  'Geometry': {'BoundingBox': {'Width': 0.050695355981588364,
#    'Height': 0.00911602471023798,
#    'Left': 0.5098308324813843,
#    'Top': 0.06109482795000076},
#   'Polygon': [{'X': 0.5098308324813843, 'Y': 0.06109482795000076},
#    {'X': 0.5605247616767883, 'Y': 0.06110827252268791},
#    {'X': 0.5605261921882629, 'Y': 0.07021085172891617},
#    {'X': 0.5098321437835693, 'Y': 0.07019741833209991}]},
#  'Id': '0da4ccfb-af62-4e61-946e-0751691c54fd',
#  'Relationships': [{'Type': 'CHILD',
#    'Ids': ['f59da04d-8410-4a67-a317-f0ecc77d4ed5']}],
#  'Page': 1}

# %%
[block for block in all_blocks if block["BlockType"] == "TABLE"]
# Out:
# [{'BlockType': 'TABLE',
#   'Confidence': 99.89390563964844,
#   'Geometry': {'BoundingBox': {'Width': 0.5087794661521912,
#     'Height': 0.26766061782836914,
#     'Left': 0.053847137838602066,
#     'Top': 0.24279743432998657},
#    'Polygon': [{'X': 0.053847137838602066, 'Y': 0.24279743432998657},
#     {'X': 0.5625845193862915, 'Y': 0.242930606007576},
#     {'X': 0.5626266002655029, 'Y': 0.5104580521583557},
#     {'X': 0.053862061351537704, 'Y': 0.5103273987770081}]},
#   'Id': '9a7a261e-6b0e-4302-81e1-adbe196710ea',
#   'Relationships': [{'Type': 'CHILD',
#     'Ids': ['4ffd9a58-59b3-4b04-858f-415668f72933',
#      'a120511a-3b69-4102-99ca-29a4405ae598',
#      'ff3502fc-e56b-49d1-a425-8faa18a9629d',
#      'f07e33e6-73ec-44fa-bec9-c3790d9d8fca',
#      '859f80e3-15ce-44b5-8ad3-2feeded40f91',
#      '1faa41af-3fb4-4a27-b26c-38aef38d6d6c',
#      '9afeaef3-709a-4db2-8314-5129f6793cfa',
#      '3b693cb3-b3d2-4961-a69b-cc805b93bb5b',
# ...

# %%
[block for block in all_blocks if block["Id"] in ['5d661445-c579-40c4-a026-59c37c9f59ba', '3f6ffa14-dd68-459f-a198-a1038e7839f7', '22e5abb8-97fc-4e9a-9853-1ada4e583a4c', 'c57b0b6b-f702-43a8-926b-907c1880ca93', '826d1048-c4b5-4682-9a81-96001a5e6569', '0030f2a8-93d1-459e-a608-ed3af11c1931', '1ab99e5c-9d5f-447a-bdbd-98423f1d37e2', 'db6aba99-cdb3-430e-9b86-02fe9bee57e1', '5582dd41-33e8-4a52-8500-7999dbedeffb', 'c17f5bd7-55a7-42ce-95b8-694e09bb6e63', '4438ea6f-274f-4531-9931-981af28205e1', 'a792fdda-d7f3-4219-8293-b5b0b38bdf7e', '8c62ff1f-d923-4724-bac8-4aa43ede8dc1', '4c57a92a-18e7-46fa-86ed-5f80e1d781f5', '07544403-58c6-4716-a6b8-a6fc14d3300d', 'ed7b5182-a681-4bff-a906-c1c9f4ce3d1e', 'e3265c9e-6a4f-4d5e-90ff-e26444338fc0']]
# Out:
# [{'BlockType': 'MERGED_CELL',
#   'Confidence': 87.75479125976562,
#   'RowIndex': 1,
#   'ColumnIndex': 1,
#   'RowSpan': 2,
#   'ColumnSpan': 2,
#   'Geometry': {'BoundingBox': {'Width': 0.09882353991270065,
#     'Height': 0.04482848197221756,
#     'Left': 0.5155553221702576,
#     'Top': 0.21684938669204712},
#    'Polygon': [{'X': 0.5155553221702576, 'Y': 0.21697746217250824},
#     {'X': 0.6143016815185547, 'Y': 0.21684938669204712},
#     {'X': 0.6143788695335388, 'Y': 0.26155024766921997},
#     {'X': 0.5156310200691223, 'Y': 0.2616778612136841}]},
#   'Id': '5d661445-c579-40c4-a026-59c37c9f59ba',
#   'Relationships': [{'Type': 'CHILD',
#     'Ids': ['ef1f4d20-9fe8-4552-a3e6-19fef2d86c5a',
#      'c5bd1be6-9e8e-4d08-b55a-4fad2ea5729e',
#      'f0cfd1f0-4e4f-4a8b-b7c6-07e6d1fbb6e4',
#      'a9caf3ee-45c4-4965-a2e0-4a76346d4fb7']}],
#   'EntityTypes': ['COLUMN_HEADER'],
#   'Page': 3},
#  {'BlockType': 'MERGED_CELL',
#   'Confidence': 84.16907501220703,
#   'RowIndex': 1,
# ...

# %%
[block for block in all_blocks if block["Id"] in ['408263f6-560d-4d7f-b7cc-ad7b5c7169e3',
     'cf76ec90-91c8-43ef-b2c2-20a6bf816413','baedbabe-2648-42b7-b47e-e48e7232bbdd',]]
# Out:
# [{'BlockType': 'WORD',
#   'Confidence': 99.82345581054688,
#   'Text': 'Unit',
#   'TextType': 'PRINTED',
#   'Geometry': {'BoundingBox': {'Width': 0.016722707077860832,
#     'Height': 0.008203715085983276,
#     'Left': 0.6199806928634644,
#     'Top': 0.2358769327402115},
#    'Polygon': [{'X': 0.6199806928634644, 'Y': 0.23589856922626495},
#     {'X': 0.6366891860961914, 'Y': 0.2358769327402115},
#     {'X': 0.636703372001648, 'Y': 0.2440590262413025},
#     {'X': 0.6199948191642761, 'Y': 0.24408064782619476}]},
#   'Id': 'baedbabe-2648-42b7-b47e-e48e7232bbdd',
#   'Page': 3},
#  {'BlockType': 'CELL',
#   'Confidence': 84.16907501220703,
#   'RowIndex': 1,
#   'ColumnIndex': 3,
#   'RowSpan': 1,
#   'ColumnSpan': 1,
#   'Geometry': {'BoundingBox': {'Width': 0.02641923725605011,
#     'Height': 0.019917815923690796,
#     'Left': 0.6143019795417786,
#     'Top': 0.21699370443820953},
#    'Polygon': [{'X': 0.6143019795417786, 'Y': 0.2170279175043106},
# ...

# %% [markdown]
# ## BlockType
# These are the available block type from textract
# ['WORD', 'PAGE', 'TABLE', 'MERGED_CELL', 'CELL', 'LINE']

# %%
table_blocks = [block for block in all_blocks if block["BlockType"] == "TABLE"]

# %%
table_blocks[1]["Relationships"]
# Out:
# [{'Type': 'CHILD',
#   'Ids': ['644ac220-93cc-4c68-ac7f-22e8dd2acdb0',
#    '1d0093dc-603a-4275-a272-8dbac59ad11e',
#    '38c2a451-6050-4a79-8733-71e4677571bd',
#    'dbd45946-8047-4a00-914b-4ba0d3f8ae01',
#    'd829bec8-be83-4f18-aad2-7d8c5e5d9a88',
#    'cf24096a-056f-426d-b6d1-51223e9ae731',
#    '92102469-f133-407d-baa1-0227637a9135',
#    'cb5c87bb-bba5-4b58-87d6-50efe7dce490',
#    '6bc1c8bf-fa90-4fae-95aa-e780c6169ba0',
#    'c73809a2-6dc3-4e02-9827-b676965ba50a',
#    '5287664f-c5e0-4242-849a-c5b1d0f505f0',
#    '7e1cb507-a439-42b7-8bb7-50b6f6bf3130',
#    '69d0f966-4613-4166-9f4d-ff01a0a29b82',
#    '11576879-81a3-46da-ae47-eb2f3c161869',
#    '3b018752-c697-4c79-8e7d-6f3ddccb22cb',
#    'a92fb4d1-dadb-476f-b1e6-19592ad67934',
#    '138f644e-7a4d-4047-a39d-6cc0db490479',
#    'bb29581c-c1a3-400c-aa87-6aa18cd767ad',
#    'aabb58bc-febd-4a2b-9bd0-f932fad2db37',
#    '57e0f58c-3c5a-4717-bf37-0bc56f7cb91f',
#    'eec4822b-b14d-4ac1-9f76-84464878e08c',
# ...

# %%
[block for block in all_blocks if block["Id"] in ['1f03ad59-3087-4f6f-94d3-3530a7367418', '487a675f-b69a-4318-9876-657c71aa8e5e']]
# Out:
# [{'BlockType': 'CELL',
#   'Confidence': 67.56656646728516,
#   'RowIndex': 2,
#   'ColumnIndex': 3,
#   'RowSpan': 1,
#   'ColumnSpan': 1,
#   'Geometry': {'BoundingBox': {'Width': 0.05936727300286293,
#     'Height': 0.04404550418257713,
#     'Left': 0.7079449892044067,
#     'Top': 0.2770346701145172},
#    'Polygon': [{'X': 0.7079449892044067, 'Y': 0.2770346701145172},
#     {'X': 0.7673035264015198, 'Y': 0.2770501971244812},
#     {'X': 0.767312228679657, 'Y': 0.32108017802238464},
#     {'X': 0.707953155040741, 'Y': 0.3210647404193878}]},
#   'Id': '1f03ad59-3087-4f6f-94d3-3530a7367418',
#   'Page': 1},
#  {'BlockType': 'CELL',
#   'Confidence': 67.56656646728516,
#   'RowIndex': 3,
#   'ColumnIndex': 3,
#   'RowSpan': 1,
#   'ColumnSpan': 1,
#   'Geometry': {'BoundingBox': {'Width': 0.059367623180150986,
#     'Height': 0.043182872235774994,
#     'Left': 0.707953155040741,
#     'Top': 0.3210647404193878},
#    'Polygon': [{'X': 0.707953155040741, 'Y': 0.3210647404193878},
# ...

# %%
[block for block in all_blocks if block["Id"] in ['f21acacd-3e24-4cf5-8308-c62db92d878d',
     'f0e4698a-1029-4e5b-b5f6-f42443291884',
     '15800f48-3750-4d06-84ba-0094c3e11f6d',
     '56089910-65f8-4647-9b5b-056088bca1c1',
     '50374c3e-3a8e-488d-a882-0f18683246a0']]
# Out:
# [{'BlockType': 'WORD',
#   'Confidence': 55.55833053588867,
#   'Text': 'CO2',
#   'TextType': 'PRINTED',
#   'Geometry': {'BoundingBox': {'Width': 0.013903200626373291,
#     'Height': 0.011501514352858067,
#     'Left': 0.047238338738679886,
#     'Top': 0.6463883519172668},
#    'Polygon': [{'X': 0.047242749482393265, 'Y': 0.6463887691497803},
#     {'X': 0.06114153936505318, 'Y': 0.6463883519172668},
#     {'X': 0.06113723665475845, 'Y': 0.6578894257545471},
#     {'X': 0.047238338738679886, 'Y': 0.6578898429870605}]},
#   'Id': 'f21acacd-3e24-4cf5-8308-c62db92d878d',
#   'Page': 1},
#  {'BlockType': 'WORD',
#   'Confidence': 99.72694396972656,
#   'Text': 'Scope',
#   'TextType': 'PRINTED',
#   'Geometry': {'BoundingBox': {'Width': 0.024745484814047813,
#     'Height': 0.011002779006958008,
#     'Left': 0.0691058561205864,
#     'Top': 0.6463977098464966},
#    'Polygon': [{'X': 0.06910990178585052, 'Y': 0.6463984847068787},
# ...

# %%
[block for block in all_blocks if block["Id"]=="e35a484b-2d46-46a6-9c41-6edc53b0b2be"]
# Out:
# [{'BlockType': 'WORD',
#   'Confidence': 99.37969207763672,
#   'Text': 'data*',
#   'TextType': 'PRINTED',
#   'Geometry': {'BoundingBox': {'Width': 0.024252884089946747,
#     'Height': 0.00969074759632349,
#     'Left': 0.5782848596572876,
#     'Top': 0.6128990054130554},
#    'Polygon': [{'X': 0.5782849192619324, 'Y': 0.6128996014595032},
#     {'X': 0.6025376319885254, 'Y': 0.6128990054130554},
#     {'X': 0.6025377511978149, 'Y': 0.6225890517234802},
#     {'X': 0.5782848596572876, 'Y': 0.6225897073745728}]},
#   'Id': 'e35a484b-2d46-46a6-9c41-6edc53b0b2be',
#   'Page': 1}]
