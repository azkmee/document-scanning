# %% [markdown]
# ## AWS Credentials
# Check that you have entered the proper credentials in your local

# %%
AWS_ACCESS_KEY_ID="ASIAYIZMYGJZ424VCWV2"
AWS_SECRET_ACCESS_KEY="0fSZoZZl3mPiKe+XHsQYUGGIgEmKOYvhUaLd5a2P"
AWS_SESSION_TOKEN="..."
AWS_DEFAULT_REGION="ap-southeast-1"

# %%
BUCKET_NAME = 'document-scanning-az'

# %%
# !pip install amazon-textract-response-parser
# !pip install amazon-textract-prettyprinter
# !pip install amazon-textract-caller
# !pip install pandas

# %%
import boto3
import botocore
import json
import time
import pandas as pd

from trp.trp2 import TDocument, TDocumentSchema
from trp.t_pipeline import order_blocks_by_geo
from trp import Document
from textractprettyprinter.t_pretty_print import Textract_Pretty_Print, get_string
from textractcaller import get_full_json, Textract_API

# t_doc = TDocumentSchema().load(j)

# %%
session = boto3.session.Session(
    aws_access_key_id=AWS_ACCESS_KEY_ID,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY,
    aws_session_token=AWS_SESSION_TOKEN,
)

textract = session.client("textract", region_name = AWS_DEFAULT_REGION )
s3 = session.client("s3", region_name = AWS_DEFAULT_REGION)

# %% [markdown]
# Upload file if file does not exist.

# %%
filename = 'dsv'
upload_prefix = 'raw-reports/'
file_ref_raw_file = upload_prefix + filename + '.pdf'
local_file_ref = filename + '.pdf'

try:
    s3.get_object(
        Bucket= BUCKET_NAME,
        Key= file_ref_raw_file
    )
    print("File already uploaded to S3")
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "NoSuchKey":
        print("Uploading to S3")
        with open(local_file_ref, "rb") as f:
            s3.upload_fileobj(f, BUCKET_NAME, file_ref_raw_file)
        print("Uploaded to S3")

print("File is at: ", file_ref_raw_file);
# Out:
# File already uploaded to S3
# File is at:  raw-reports/dsv.pdf

# %% [markdown]
# Function to textract file asynchronously and fetch block response

# %%
def textract_file(file_ref):
    total_waiting_min = 0.00
    doc_textracted_async = textract.start_document_analysis(
        DocumentLocation={
            'S3Object':{
                'Bucket': BUCKET_NAME,
                'Name': file_ref
            }
        },
        FeatureTypes=['TABLES']
    )
    job_id = doc_textracted_async["JobId"]
    all_blocks = []
    print("getting full_json")
    response = get_full_json(job_id, Textract_API.ANALYZE, textract)
    return response

# %% [markdown]
# Get textracted file if exist from S3, else textract and upload

# %%
upload_textracted_prefix = 'textracted-reports-values/'
file_ref_tetracted = upload_textracted_prefix + filename + '.json'

document_json = {}

try:
    document_json = s3.get_object(
        Bucket= BUCKET_NAME,
        Key= file_ref_tetracted
    )
    document_json = json.loads(document_json["Body"].read().decode('UTF-8'))
    print("File already textracted")
    
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "NoSuchKey":
        print("Textracting.....")
        document_json = textract_file(file_ref_raw_file)
        print("Textracted")

        json_file = json.dumps(document_json).encode('UTF-8')

        s3.put_object(
            Body = json_file,
            Bucket = BUCKET_NAME,
            Key = file_ref_tetracted
        )
        print("File uploaded at: ", file_ref_tetracted)
all_blocks = document_json["Blocks"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 28
#      22         s3.put_object(
#      23             Body = json_file,
#      24             Bucket = BUCKET_NAME,
#      25             Key = file_ref_tetracted
#      26         )
#      27         print("File uploaded at: ", file_ref_tetracted)
# ---> 28 all_blocks = document_json["Blocks"]
#
# KeyError: 'Blocks'

# %%
print(get_string(textract_json=document_json, output_type=[Textract_Pretty_Print.TABLES]))
# Out:
# |----------------------------|------|------|------|------|------|
# | Environmental data*        | 2021 | 2020 | 2019 | 2018 | 2017 |
# | CO2 Scope 1 ('000 tonnes)  |      |      |      |      |      |
# | Company cars**             | 10   | 13   | 14   | -    | -    |
# | Road emissions (own fleet) | 101  | 43   | 37   | 39   | 39   |
# | Building emissions         | 24   | 24   | 23   | 22   | 19   |
# | Total CO, e Scope 1        | 135  | 80   | 74   | 61   | 58   |
# | CO2 Scope 2 ('000 tonnes)  |      |      |      |      |      |
# | Building emissions         | 119  | 98   | 85   | 78   | 78   |
# | Total CO2 e Scope 2        | 119  | 98   | 85   | 78   | 78   |
#
# |----------------------------|--------|--------|-------|-------|-------|
# | Environmental data*        | 2021   | 2020   | 2019  | 2018  | 2017  |
# | CO2e Scope 3 ('000 tonnes) |        |        |       |       |       |
# | Business travel**          | 1      | 1      | 8     | -     | -     |
# | Air transport              | 7,458  | 6,825  | 4,631 | 3,291 | 3,208 |
# | Sea transport              | 1,130  | 1,047  | 1,242 | 820   | 855   |
# | Road transport             | 3,823  | 3,275  | 2,847 | 3,015 | 2,987 |
# | Rail transport*            | 112    | 139    | -     | -     | -     |
# | Total CO e Scope 3         | 12,524 | 11,287 | 8,728 | 7,126 | 7,050 |
#
# |-------------------------------------------------------------|-------|-------|-------|-------|-------|
# | Environmental data*                                         | 2021  | 2020  | 2019  | 2018  | 2017  |
# | Energy efficiency (gram CO. e per tonne transported one km) |       |       |       |       |       |
# | COe (g/tonne-km) - Air transport                            | 694.4 | 704.0 | 718.2 | 728.0 | 751.0 |
# | COe (g/tonne-km) - Sea transport                            | 6.1   | 6.2   | 6.4   | 7.0   | 7.3   |
# | COe (g/tonne-km) - Road transport                           | 92.4  | 92.8  | 93.2  | 96.5  | 97.4  |
# | COe (g/tonne-km) - Rail transport*                          | 32.6  | 32,7  | -     | -     | -     |
# | Fuel consumption (own truck fleet)                          |       |       |       |       |       |
# | Total consumption of fuel ('000 gigajoule)**                | 1,488 | -     | -     | -     | -     |
# | Proportion of HVO fuel consumed (%)*                        | 4     | -     | -     | -     | -     |
# | Energy consumption Scope 1 & 2 ('000 gigajoule)             |       |       |       |       |       |
# | Total energy consumption**                                  | 2,800 | 1,673 | -     | -     | -     |
#
# |-----------------------------------------------------------------------------------------------------------|-------|-------|-------|-------|-------|
# | Environmental data*                                                                                       | 2021  | 2020  | 2019  | 2018  | 2017  |
# | Water ('000 m³)                                                                                           |       |       |       |       |       |
# | Total water consumption - buildings                                                                       | 1,188 | 1,152 | 1,596 | 1,485 | 1,435 |
# | Renewable energy share (%)                                                                                |       |       |       |       |       |
# | Renewable**                                                                                               | 12    | 22    | -     | -     | -     |
# | Non-renewable**                                                                                           | 88    | 78    | -     | -     | -     |
# | Euro engine standards (%)                                                                                 |       |       |       |       |       |
# | Sickness absence (days per FTE)                                     |       |       |       |       |       |
# | Total                                                               | 5.7   | 6.4   | 6.0   | 5.9   | 4.7   |
# | Salaried employees                                                  | 5.4   | 5.8   | 6.0   | 6.6   | 4.7   |
# | Hourly workers                                                      | 6.0   | 7.1   | 5.9   | 5.2   | 4.7   |
# | Lost Time Injury Frequency Rate (LTIFR) (per million working hours) |       |       |       |       |       |
# | Total                                                               | 4.5   | 6.7   | 5.0   | 4.6   | 4.2   |
# | Salaried employees                                                  | 1.0   | 0.8   | 0.9   | 0.5   | 0,8   |
# | Hourly workers                                                      | 7.9   | 13.3  | 9.1   | 8.3   | 7.6   |
# | Lost workdays due to lost time injury (per million working hours)   |       |       |       |       |       |
# | Total                                                               | 61.0  | 78.8  | 97.5  | 98.0  | 81.2  |
# | Salaried employees                                                  | 15.3  | 16.0  | 22.0  | 23.2  | 20.8  |
# | Hourly workers                                                      | 105,4 | 148.6 | 173,8 | 164.5 | 142.5 |
# | Fatalities                                                          |       |       |       |       |       |
# | Fatalities in absolute numbers                                      | 1     | 0     | 1     | 0     | 0     |
#
# |------------------------------------------------------|------|------|------|------|------|
# | Social data*                                         | 2021 | 2020 | 2019 | 2018 | 2017 |
# | Employee turnover ratio (%)                          |      |      |      |      |      |
# | Total                                                | 24.4 | 32.5 | 23.6 | 20.1 | 18.0 |
# | Salaried employees                                   | 24.2 | 31.5 | 21.9 | 19.6 | 18.4 |
# | Hourly workers                                       | 24.6 | 33.6 | 25.3 | 20.6 | 17.5 |
# | Employee turnover ratio (%) (adjusted for synergies) |      |      |      |      |      |
# | Total                                                | 21.9 | 20.5 | 21.1 | 20.1 | 16.4 |
# | Salaried employees                                   | 19.7 | 11.7 | 17.5 | 19.6 | 15.7 |
# | Hourly workers                                       | 24.2 | 31.0 | 24.8 | 20.6 | 17.2 |
#
# |---------------------------------------------------------------------------|------|------|------|------|------|
# | Governance and other data*                                                | 2021 | 2020 | 2019 | 2018 | 2017 |
# | Compliance reviews (%)                                                    |      |      |      |      |      |
# | Companies reviewed                                                        | 25   | 25   | 56   | 50   | 55   |
# | Management System Certifications (%)                                      |      |      |      |      |      |
# | ISO 9001 (Quality)                                                        | 32   | 38   | 61   | 40   | 39   |
# | ISO 45001 (Health & Safety)                                               | 18   | 22   | 40   | 19   | 12   |
# | ISO 14001 (Environment)                                                   | 24   | 30   | 52   | 33   | 24   |
# | Distribution of DSV's Supplier Code of Conduct (%)                        |      |      |      |      |      |
# | Distribution of DSV's Supplier Code of Conduct with spend over 25,000 EUR | 88   | 100  | 100  | 95   | 93   |
#
# |----------------------------------------------------------------------------------------------------------|------|------|------|------|------|
# | Governance and other data*                                                                               | 2021 | 2020 | 2019 | 2018 | 2017 |
# | Employee training on Code of Conduct, including human rights and anti-corruption policies and procedures |      |      |      |      |      |
# | Code of Conduct online training, completion rate (%)                                                     | 100  | 100  | 100  | -    | -    |
# | Average training hours spent on Code of Conduct*                                                         | 2    | 2    | 2    | -    | -    |
# | Whistleblower reports                                                                                    |      |      |      |      |      |
# | Total                                                                                                    | 47   | 41   | 60   | 23   | 23   |

# %%
## from trp import Document
from array import *
import numpy as np

doc = Document(document_json)

table_num = 0

all_array = []


# Iterate over elements in the document
for p, page in enumerate(doc.pages):
    print("Page number: {}".format(p+1))
    
    # Print tables
    for t, table in enumerate(page.tables):
        table_array = []
        print("Table number: {}".format(t+1))

        for r, row in enumerate(table.rows):
            row_array = []
            for c, cell in enumerate(row.cells):
                row_array.append(cell.text.strip())
                print("Table[{}][{}] = {}-{}".format(r, c, cell.text, cell.confidence))
            table_array.append(row_array)
        all_array.append(table_array)
        print("\n")
        
print(all_array)
print(len(all_array))
# Out:
# Page number: 1
# Table number: 1
# Table[0][0] = Environmental data* -93.20857238769531
# Table[0][1] = 2021 -91.46683502197266
# Table[0][2] = 2020 -92.3075942993164
# Table[0][3] = 2019 -91.76325225830078
# Table[0][4] = 2018 -92.98519134521484
# Table[0][5] = 2017 -88.92678833007812
# Table[1][0] = CO2 Scope 1 ('000 tonnes) -54.89760208129883
# Table[1][1] = -54.89760208129883
# Table[1][2] = -54.89760208129883
# Table[1][3] = -54.89760208129883
# Table[1][4] = -54.89760208129883
# Table[1][5] = -54.89760208129883
# Table[2][0] = Company cars** -85.4514389038086
# Table[2][1] = 10 -83.85466003417969
# Table[2][2] = 13 -84.62545013427734
# Table[2][3] = 14 -84.12640380859375
# Table[2][4] = - -85.24665069580078
# Table[2][5] = - -81.5260009765625
# Table[3][0] = Road emissions (own fleet) -89.71946716308594
# Table[3][1] = 101 -88.04293823242188
# Table[3][2] = 43 -88.85222625732422
# Table[3][3] = 37 -88.32825469970703
# Table[3][4] = 39 -89.50445556640625
# Table[3][5] = 39 -85.59797668457031
# Table[4][0] = Building emissions -91.32218933105469
# Table[4][1] = 24 -89.61570739746094
# Table[4][2] = 24 -90.439453125
# Table[4][3] = 23 -89.9061279296875
# Table[4][4] = 22 -91.10334014892578
# Table[4][5] = 19 -87.1270751953125
# Table[5][0] = Total CO, e Scope 1 -90.95220947265625
# Table[5][1] = 135 -89.25263977050781
# Table[5][2] = 80 -90.07305145263672
# Table[5][3] = 74 -89.54187774658203
# Table[5][4] = 61 -90.73423767089844
# Table[5][5] = 58 -86.77407836914062
# Table[6][0] = CO2 Scope 2 ('000 tonnes) -51.393943786621094
# Table[6][1] = -51.393943786621094
# Table[6][2] = -51.393943786621094
# Table[6][3] = -51.393943786621094
# Table[6][4] = -51.393943786621094
# Table[6][5] = -51.393943786621094
# Table[7][0] = Building emissions -68.72660827636719
# Table[7][1] = 119 -67.4423599243164
# Table[7][2] = 98 -68.06228637695312
# Table[7][3] = 85 -67.66091918945312
# Table[7][4] = 78 -68.56190490722656
# Table[7][5] = 78 -65.5694808959961
# Table[8][0] = Total CO2 e Scope 2 -92.24761962890625
# Table[8][1] = 119 -90.52384185791016
# Table[8][2] = 98 -91.3559341430664
# Table[8][3] = 85 -90.81720733642578
# Table[8][4] = 78 -92.02655029296875
# Table[8][5] = 78 -88.0099868774414
#
#
# Table number: 2
# 10

# %%
# arr = all_array[0]
# arr_np = np.array(arr)
# print(arr_np)
# arr_np = np.transpose(arr_np)
# print(arr_np)
# df = pd.DataFrame(arr_np[1:], columns=arr_np[0])
# df
# Out:
# [['Environmental data*' '2021' '2020' '2019' '2018' '2017']
#  ["CO2 Scope 1 ('000 tonnes)" '' '' '' '' '']
#  ['Company cars**' '10' '13' '14' '-' '-']
#  ['Road emissions (own fleet)' '101' '43' '37' '39' '39']
#  ['Building emissions' '24' '24' '23' '22' '19']
#  ['Total CO, e Scope 1' '135' '80' '74' '61' '58']
#  ["CO2 Scope 2 ('000 tonnes)" '' '' '' '' '']
#  ['Building emissions' '119' '98' '85' '78' '78']
#  ['Total CO2 e Scope 2' '119' '98' '85' '78' '78']]
# [['Environmental data*' "CO2 Scope 1 ('000 tonnes)" 'Company cars**'
#   'Road emissions (own fleet)' 'Building emissions' 'Total CO, e Scope 1'
#   "CO2 Scope 2 ('000 tonnes)" 'Building emissions' 'Total CO2 e Scope 2']
#  ['2021' '' '10' '101' '24' '135' '' '119' '119']
#  ['2020' '' '13' '43' '24' '80' '' '98' '98']
#  ['2019' '' '14' '37' '23' '74' '' '85' '85']
#  ['2018' '' '-' '39' '22' '61' '' '78' '78']
#  ['2017' '' '-' '39' '19' '58' '' '78' '78']]
#   Environmental data* CO2 Scope 1 ('000 tonnes) Company cars**  \
# 0                2021                                       10
# 1                2020                                       13
# 2                2019                                       14
# 3                2018                                        -
# 4                2017                                        -
#
#   Road emissions (own fleet) Building emissions Total CO, e Scope 1  \
# 0                        101                 24                 135
# 1                         43                 24                  80
# 2                         37                 23                  74
# 3                         39                 22                  61
# 4                         39                 19                  58
#
#   CO2 Scope 2 ('000 tonnes) Building emissions Total CO2 e Scope 2
# 0                                          119                 119
# 1                                           98                  98
# 2                                           85                  85
# 3                                           78                  78
# 4                                           78                  78

# %%
# arr = all_array[1]
# arr_np = np.array(arr)
# arr_np = np.transpose(arr_np)
# df = pd.DataFrame(arr_np[1:], columns=arr_np[0])
# df
# Out:
#   Environmental data*  CO2e Scope 3 ('000 tonnes)  Business travel**   \
# 0                2021                                              1
# 1                2020                                              1
# 2                2019                                              8
# 3                2018                                              -
# 4                2017                                              -
#
#   Air transport  Sea transport  Road transport  Rail transport*   \
# 0         7,458          1,130           3,823              112
# 1         6,825          1,047           3,275              139
# 2         4,631          1,242           2,847                -
# 3         3,291            820           3,015                -
# 4         3,208            855           2,987                -
#
#   Total CO e Scope 3
# 0             12,524
# 1             11,287
# 2              8,728
# 3              7,126
# 4              7,050

# %%
import re

def is_header_years(header_array):
    is_years = True
    for idx, i in enumerate(header_array):
        if idx>0:
            if not re.match(r"(19|20|21)[0-9]{2}", i):
                is_years = False
                break

    return is_years

def change_label_to_years_after_checking(header_array):
    if is_header_years(header_array):
        header_array[0] = "Years"
    
    return header_array

for idx, table in enumerate(all_array):
    headers = table[0]
    headers = change_label_to_years_after_checking(headers)
    table[0] = headers
# Out:
# [['Years', '2021', '2020', '2019', '2018', '2017'], ["CO2 Scope 1 ('000 tonnes)", '', '', '', '', ''], ['Company cars**', '10', '13', '14', '-', '-'], ['Road emissions (own fleet)', '101', '43', '37', '39', '39'], ['Building emissions', '24', '24', '23', '22', '19'], ['Total CO, e Scope 1', '135', '80', '74', '61', '58'], ["CO2 Scope 2 ('000 tonnes)", '', '', '', '', ''], ['Building emissions', '119', '98', '85', '78', '78'], ['Total CO2 e Scope 2', '119', '98', '85', '78', '78']]

# %%
tables = all_array
df_arr = []
for arr in tables:   
    arr_np = np.array(arr)
    arr_np = np.transpose(arr_np)
    df = pd.DataFrame(arr_np[1:], columns=arr_np[0])
    df_arr.append(df)
    
df_merge = df_arr[0]
for df in df_arr[1:]:
    df_merge = pd.merge(df_merge, df, on='Years')
    
df_merge
# Out:
# C:\Users\azmi_\AppData\Local\Temp\ipykernel_43076\1512791222.py:11: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Total_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merge = pd.merge(df_merge, df, on='Years')
#   Years CO2 Scope 1 ('000 tonnes) Company cars** Road emissions (own fleet)  \
# 0  2021                                       10                        101
# 1  2020                                       13                         43
# 2  2019                                       14                         37
# 3  2018                                        -                         39
# 4  2017                                        -                         39
#
#   Building emissions Total CO, e Scope 1 CO2 Scope 2 ('000 tonnes)  \
# 0                 24                 135
# 1                 24                  80
# 2                 23                  74
# 3                 22                  61
# 4                 19                  58
#
#   Building emissions Total CO2 e Scope 2 CO2e Scope 3 ('000 tonnes)  ...  \
# 0                119                 119                             ...
# 1                 98                  98                             ...
# 2                 85                  85                             ...
# 3                 78                  78                             ...
# 4                 78                  78                             ...
#
#   ISO 9001 (Quality) ISO 45001 (Health & Safety) ISO 14001 (Environment)  \
# 0                 32                          18                      24
# 1                 38                          22                      30
# 2                 61                          40                      52
# 3                 40                          19                      33
# 4                 39                          12                      24
#
#   Distribution of DSV's Supplier Code of Conduct (%)  \
# 0
# 1
# 2
# 3
# 4
#
#   Distribution of DSV's Supplier Code of Conduct with spend over 25,000 EUR  \
# 0                                                 88
# 1                                                100
# 2                                                100
# 3                                                 95
# 4                                                 93
#
#   Employee training on Code of Conduct, including human rights and anti-corruption policies and procedures  \
# 0
# 1
# 2
# 3
# 4
#
#   Code of Conduct online training, completion rate (%)  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                  -
# 4                                                  -
#
#   Average training hours spent on Code of Conduct* Whistleblower reports  \
# 0                                                2
# 1                                                2
# 2                                                2
# 3                                                -
# 4                                                -
#
#   Total_y
# 0      47
# 1      41
# 2      60
# 3      23
# 4      23
#
# [5 rows x 99 columns]

# %% [markdown]
# ## BlockType
# These are the available block type from textract
# ['WORD', 'PAGE', 'TABLE', 'MERGED_CELL', 'CELL', 'LINE']

# %%
table_blocks = [block for block in all_blocks if block["BlockType"] == "TABLE"]

# %%
table_blocks[1]["Relationships"]
# Out:
# [{'Type': 'CHILD',
#   'Ids': ['f36ff0f7-7679-4a73-842b-857cc23f8157',
#    'b9af3bee-c4c8-4d29-9526-49e222419249',
#    '1239a0c2-8266-4699-8647-cb87c56125b2',
#    'e3b5d944-8622-42d2-8e89-e555a49e71d3',
#    '18c12f14-9981-45d8-b142-61cd6003df61',
#    'e7e63d29-7fd7-4f3f-b774-baebc7a2b375',
#    '0a46d563-1fc3-4f85-b7dc-3f81e41f7194',
#    'ede5af71-75e3-4190-ab35-887ccba6a7a9',
#    '4a226c2c-9e44-444e-b973-51ff2815f71f',
#    '373ae6e6-3a64-4cb1-ade6-06bb113f8586',
#    'bebd37a0-a08f-45d4-9c1b-286c6eca0930',
#    '8984e03d-c73c-45d8-abb7-9eee83be97c6',
#    'bf6e25f7-5288-4e60-b699-8ae120582258',
#    '08ccd005-2e16-4ebd-97d1-fbbe36184c5e',
#    '83a8acf7-6af6-42fd-bfa3-ac823d4aff50',
#    '1c18a0c3-b16d-4ac0-9458-d1626116cdb4',
#    'a6b2ebb4-c230-4631-95dd-91c14e705a57',
#    '37a4f424-a7f2-4f00-b15b-eee80f8c5621',
#    '655637ca-a2ee-4142-b67b-fbcf5eafc97e',
#    '0632914b-2f19-45f8-9b8f-20239558a704',
#    'aab77dd3-3b68-445f-88e3-f1b82d93c074',
#    'dc4b4c13-3608-4652-b435-d3b0aa3c1b92',
#    '07da0f0a-f1f7-4b52-ab30-e8735304d979',
#    '7375b6f5-3958-44aa-83a2-beac0327a37b',
#    'b235481d-1b94-4963-88fa-5c1f088a4828',
#    '75af63fa-da2d-471c-8dad-a0c4ea527f37',
#    '96f99fd2-6d36-4858-843d-873a6d69cffd',
#    'db73c7ed-0a95-4ba2-8cf4-211acc8e796a',
#    '7c8708eb-83da-435a-9d18-24a999d6190a',
#    '179ab12f-c266-403a-864a-647bc117c7fe',
#    '0c11088a-5ec2-4aab-98d4-0c507e572b80',
#    '0f7a6f74-3254-4a63-ad32-90f43a915cf9',
#    '17799057-d485-41bd-a1af-879aeb4eef36',
#    'c3811274-4f47-4724-b52c-898b68400a70',
#    '24cb0b10-21ba-44e7-b9ac-264d83ae206d',
#    'b2b91c10-59c5-4961-97c4-aa903edcb824',
#    '7b684854-dea5-4ce3-982c-53515536d6a3',
#    '62d7bb04-f445-476a-b9c9-d7e605ac2c69',
#    '68b05e99-7dd6-4cbf-8de5-0f06effd06fc',
#    '8fbc18aa-f1ae-4a4f-96ce-c845acbdf177',
#    '8d4a3e29-de85-4ebf-b3da-de6bb913d571',
#    '41c32616-b579-4212-b3f2-f8529acd0e17',
#    'd1fac2d1-3488-43f2-b264-b06e5d24bafd',
#    'f762caae-6d8a-49fc-ab3d-6c5e04905319',
#    'faa9b4d7-d983-40bd-85c9-b5b2fcafc4e5',
#    'de430880-4c1e-4307-9979-8db64004d0a9',
#    'd4b6b7cd-8579-4aa0-9eaa-ec406759e8cc',
#    '34b07ad9-31ac-4c09-86c3-a49f33d41fca']},
#  {'Type': 'MERGED_CELL', 'Ids': ['a28dcb57-2303-4e3e-ad06-77df7f8e6c22']}]

# %%
[block for block in all_blocks if block["Id"]=="b9af3bee-c4c8-4d29-9526-49e222419249"]
# Out:
# [{'BlockType': 'CELL',
#   'Confidence': 91.58930206298828,
#   'RowIndex': 1,
#   'ColumnIndex': 2,
#   'RowSpan': 1,
#   'ColumnSpan': 1,
#   'Geometry': {'BoundingBox': {'Width': 0.051706261932849884,
#     'Height': 0.024867210537195206,
#     'Left': 0.7049752473831177,
#     'Top': 0.6056995987892151},
#    'Polygon': [{'X': 0.7049752473831177, 'Y': 0.6057009100914001},
#     {'X': 0.756678581237793, 'Y': 0.6056995987892151},
#     {'X': 0.7566815614700317, 'Y': 0.630565345287323},
#     {'X': 0.7049773335456848, 'Y': 0.6305668354034424}]},
#   'Id': 'b9af3bee-c4c8-4d29-9526-49e222419249',
#   'Relationships': [{'Type': 'CHILD',
#     'Ids': ['46d8b3d7-ce53-4dfe-8bdc-925ab8444b7b']}],
#   'EntityTypes': ['COLUMN_HEADER'],
#   'Page': 1}]

# %%
[block for block in all_blocks if block["Id"]=="46d8b3d7-ce53-4dfe-8bdc-925ab8444b7b"]
# Out:
# [{'BlockType': 'WORD',
#   'Confidence': 99.8606948852539,
#   'Text': '2021',
#   'TextType': 'PRINTED',
#   'Geometry': {'BoundingBox': {'Width': 0.021340342238545418,
#     'Height': 0.008796324953436852,
#     'Left': 0.7253584265708923,
#     'Top': 0.6139723658561707},
#    'Polygon': [{'X': 0.7253584265708923, 'Y': 0.6139729619026184},
#     {'X': 0.7466977834701538, 'Y': 0.6139723658561707},
#     {'X': 0.746698796749115, 'Y': 0.6227681040763855},
#     {'X': 0.7253592610359192, 'Y': 0.6227687001228333}]},
#   'Id': '46d8b3d7-ce53-4dfe-8bdc-925ab8444b7b',
#   'Page': 1}]

# %%
[block for block in all_blocks if block["Id"]=="e35a484b-2d46-46a6-9c41-6edc53b0b2be"]
# Out:
# [{'BlockType': 'WORD',
#   'Confidence': 99.37969207763672,
#   'Text': 'data*',
#   'TextType': 'PRINTED',
#   'Geometry': {'BoundingBox': {'Width': 0.024252884089946747,
#     'Height': 0.00969074759632349,
#     'Left': 0.5782848596572876,
#     'Top': 0.6128990054130554},
#    'Polygon': [{'X': 0.5782849192619324, 'Y': 0.6128996014595032},
#     {'X': 0.6025376319885254, 'Y': 0.6128990054130554},
#     {'X': 0.6025377511978149, 'Y': 0.6225890517234802},
#     {'X': 0.5782848596572876, 'Y': 0.6225897073745728}]},
#   'Id': 'e35a484b-2d46-46a6-9c41-6edc53b0b2be',
#   'Page': 1}]

# %%
# human_loop_config={
#     'HumanLoopName': 'document-scanning-human-review',
#     'FlowDefinitionArn':'arn:aws:sagemaker:ap-southeast-1:568640156275:flow-definition/document-scanning-human-review'
# }

# %%
# doc_textracted_sync = textract.analyze_document(
#     Document={
#         'S3Object':{
#             'Bucket': BUCKET_NAME,
#             'Name': file_ref
#         }
#     },
#     FeatureTypes=['TABLES','FORMS'],
#     HumanLoopConfig=human_loop_config
# )
